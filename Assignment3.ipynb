# %%
import numpy as np
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.datasets import mnist

# %%
(x_train, y_train), (x_test,y_test) = mnist.load_data()
x_train = x_train/255
x_test = x_test/255
print(x_train.shape)
# Out:
# (60000, 28, 28)

# %%
import matplotlib.pyplot as plt
import random
n = random.randint(1, 1000)
plt.imshow(x_train[n])
plt.show()
print(y_train[n])
# Out:
# 7

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (60000, 28, 28)
# (60000,)

# %%
x_train = x_train.reshape(x_train.shape[0], 784)
x_test_nonreshape = x_test.copy()
x_test = x_test.reshape(x_test.shape[0], 784)
print(x_test_nonreshape.shape)
# Out:
# (10000, 28, 28)

# %%
x_train.shape
# Out:
# (60000, 784)

# %%
model = Sequential()

# %%
model.add(Dense(200, activation='relu'))

# %%
model.add(Dense(100, activation='relu'))

# %%
#output layer
model.add(Dense(10, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#model.summary()

# %%
history = model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2219 - accuracy: 0.9341
# Epoch 2/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0887 - accuracy: 0.9731
# Epoch 3/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0619 - accuracy: 0.9808
# Epoch 4/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0452 - accuracy: 0.9858
# Epoch 5/5
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0367 - accuracy: 0.9879

# %%
model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0791 - accuracy: 0.9777
# [0.07908858358860016, 0.9776999950408936]

# %%
x_test.shape
print(x_test_nonreshape.shape)
print(x_test.shape)
# Out:
# (10000, 28, 28)
# (10000, 784)

# %%
for i in range(5):
    n = random.randint(0, 10000)
    plt.imshow(x_test_nonreshape[n])
    plt.show()
    predicted = model.predict(x_test)
    output = np.argmax(predicted[n])
    print(f'Predicted value is: {output}')
    for i in range(10):
        print(f'Prediction of {i}: {predicted[n][i]}')
# Out:
# 313/313 [==============================] - 0s 1ms/step
# Predicted value is: 4
# Prediction of 0: 2.8759097403963096e-05
# Prediction of 1: 0.28426551818847656
# Prediction of 2: 0.06393703818321228
# Prediction of 3: 0.01379343867301941
# Prediction of 4: 0.9999845623970032
# Prediction of 5: 0.0003583609650377184
# Prediction of 6: 1.3938425581727643e-05
# Prediction of 7: 0.9773461818695068
# Prediction of 8: 0.00025403161998838186
# Prediction of 9: 0.9498556852340698
# 313/313 [==============================] - 0s 1ms/step
# Predicted value is: 7
# Prediction of 0: 0.12280285358428955
# Prediction of 1: 0.005404564552009106
# Prediction of 2: 0.40295615792274475
# Prediction of 3: 0.0906452015042305
# Prediction of 4: 0.017135677859187126
# Prediction of 5: 8.776164031587541e-05
# Prediction of 6: 4.348205038695596e-06
# Prediction of 7: 0.9999585747718811
# Prediction of 8: 0.016028741374611855
# Prediction of 9: 0.9997851848602295
# ...

# %%
loss = history.history['loss']
accuracy = history.history['accuracy']
epochs = range(5)
plt.plot(epochs, loss, 'g', label='loss')
plt.plot(epochs, accuracy, 'b', label='accuracy')
plt.title("Loss and Accuracy")
plt.xlabel("Loss")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
