# %%
import pandas as pd
import os
import numpy as np

# %%
df = pd.read_csv("./datasets/cifar10/train.csv")

# %%
df
# Out:
#        pixel_0  pixel_1  pixel_2  pixel_3  pixel_4  pixel_5  pixel_6  pixel_7  \
# 0           59       43       50       68       98      119      139      145
# 1          154      126      105      102      125      155      172      180
# 2          255      253      253      253      253      253      253      253
# 3           28       37       38       42       44       40       40       24
# 4          170      168      177      183      181      177      181      184
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 49995      145      151      156      155      153      153      157      161
# 49996      255      254      255      254      254      254      254      253
# 49997       35       40       42       39       43       45       48       51
# 49998      189      186      185      184      182      181      180      180
# 49999      229      236      234      231      236      242      246      246
#
#        pixel_8  pixel_9  ...  pixel_3063  pixel_3064  pixel_3065  pixel_3066  \
# 0          149      149  ...          58          65          59          46
# 1          142      111  ...          42          67         101         122
# 2          253      253  ...          83          80          69          66
# 3           32       43  ...          39          59          42          44
# 4          189      189  ...          88          85          82          83
# ...        ...      ...  ...         ...         ...         ...         ...
# 49995      161      161  ...          68          64          61          63
# 49996      254      254  ...          61          64          68          64
# 49997       53       56  ...          94         104         103          96
# 49998      181      180  ...         166         171         171         172
# 49999      242      236  ...         141         147         158         168
#
#        pixel_3067  pixel_3068  pixel_3069  pixel_3070  pixel_3071  label
# 0              57         104         140          84          72      6
# 1             133         136         139         142         144      9
# 2              72          79          83          83          84      9
# 3              48          38          28          37          46      4
# 4              79          78          82          78          80      1
# ...           ...         ...         ...         ...         ...    ...
# 49995          59          57          56          53          54      2
# 49996          76          82          79          81          76      6
# 49997          93          87          77          66          50      9
# 49998         169         165         169         171         171      1
# 49999         171         174         173         162         161      1
#
# [50000 rows x 3073 columns]

# %%
Y = df['label']

# %%
df = df.drop('label',axis=1)

# %%
X = []
for i in df.values:
    X.append(i)

# %%
X = np.array(X)

# %%
X
# Out:
# array([[ 59,  43,  50, ..., 140,  84,  72],
#        [154, 126, 105, ..., 139, 142, 144],
#        [255, 253, 253, ...,  83,  83,  84],
#        ...,
#        [ 35,  40,  42, ...,  77,  66,  50],
#        [189, 186, 185, ..., 169, 171, 171],
#        [229, 236, 234, ..., 173, 162, 161]])

# %%
X.shape
# Out:
# (50000, 3072)

# %%
from tensorflow.keras.models import Sequential

# %% [markdown]
# from tensorflow.keras.layers import Dense, Input

# %%
from tensorflow.keras.layers import Dense, Input
model = Sequential()

# %%
model.add(Input(shape=(3072)))
model.add(Dense(100, activation='relu'))
model.add(Dense(100, activation='relu'))
#model.add(Dense(512, activation='relu'))
model.add(Dense(10, activation='sigmoid'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, Y, epochs=10)
# Out:
# Epoch 1/10
# 2022-11-16 22:32:16.679961: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 1228800000 exceeds 10% of free system memory.
# 1563/1563 [==============================] - 5s 3ms/step - loss: 10.6139 - accuracy: 0.2126
# Epoch 2/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.4223 - accuracy: 0.2191
# Epoch 3/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.3548 - accuracy: 0.1086
# Epoch 4/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.3028 - accuracy: 0.0980
# Epoch 5/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.3028 - accuracy: 0.0981
# Epoch 6/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.3027 - accuracy: 0.0984
# Epoch 7/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.3028 - accuracy: 0.0983
# Epoch 8/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.3028 - accuracy: 0.1006
# Epoch 9/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.3028 - accuracy: 0.0988
# Epoch 10/10
# 1563/1563 [==============================] - 5s 3ms/step - loss: 2.3029 - accuracy: 0.0978
